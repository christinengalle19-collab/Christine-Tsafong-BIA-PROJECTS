# %% [markdown]
# <a href="https://colab.research.google.com/github/christinengalle19-collab/Christine-Tsafong-BIA-PROJECTS/blob/main/Connect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)


# !git config --global user.email "christinengalle19@gmail.com"
# !git config --global user.name "christine ngalle"
# Out:
# Mounted at /content/drive

# %%
#Clone repo and Create Branch
# !git clone https://github.com/christinengalle19-collab/Christine-Tsafong-BIA-PROJECTS.git

# !ls
# Out:
# Cloning into 'Christine-Tsafong-BIA-PROJECTS'...
# ...
# Christine-Tsafong-BIA-PROJECTS	drive  sample_data

# %%
with open("new_project.py", "w") as f:
    f.write("""
# Git and GitHub Exercise
def greet(name):
    return f"Hello, {name}! Welcome to Git and GitHub."
print(greet("Learner"))
""")
print("File created")
print("""
Assignment Completed:
- Git installed and configured
- Repository cloned
- File created and modified
- Changes committed
- Branch created
- Ready to push to GitHub
""")
# Out:
# File created
#
# Assignment Completed:
# - Git installed and configured
# - Repository cloned
# - File created and modified
# - Changes committed
# - Branch created
# - Ready to push to GitHub

# %%
# %pwd        # shows where you are
# %ls -la     # check if .git exists
# %cd Christine-Tsafong-BIA-PROJECTS
# Change to the cloned repository directory
# Out:
# total 28
# drwxr-xr-x 1 root root 4096 Jul 27 14:31 ./
# drwxr-xr-x 1 root root 4096 Jul 27 14:16 ../
# drwxr-xr-x 3 root root 4096 Jul 27 14:30 Christine-Tsafong-BIA-PROJECTS/
# drwxr-xr-x 4 root root 4096 Jun  4 13:32 .config/
# drwx------ 5 root root 4096 Jul 27 14:24 drive/
# -rw-r--r-- 1 root root  124 Jul 27 14:31 new_project.py
# drwxr-xr-x 1 root root 4096 Jun  4 13:32 sample_data/
# /content/Christine-Tsafong-BIA-PROJECTS

# %%
# !git add new_project.py.py
# !git commit -m "Add initial notebook with greeting function"

# The token is already in the remote URL from previous steps, so we don't need to re-add it here unless the remote URL changed
# Out:
# fatal: pathspec 'new_project.py.py' did not match any files
# On branch main
#
# Initial commit
#
# nothing to commit (create/copy files and use "git add" to track)

# %%
# !mv /content/new_project.py .

# %%
# !git add new_project.py
# !git commit -m "Add new_project.py with greeting function"
# Out:
# [main (root-commit) d91d3bc] Add new_project.py with greeting function
#  1 file changed, 5 insertions(+)
#  create mode 100644 new_project.py

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
from getpass import getpass
import os

# Prompt the user for their GitHub PAT
github_token = getpass('Enter your GitHub Personal Access Token (PAT): ')

# Get the current remote URL
# !git remote set-url origin https://{github_token}@github.com/christinengalle19-collab/Christine-Tsafong-BIA-PROJECTS.git

# Now try pushing again
# !git push origin main
# Out:
# Enter your GitHub Personal Access Token (PAT): ··········
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 346 bytes | 346.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/christinengalle19-collab/Christine-Tsafong-BIA-PROJECTS.git
#  * [new branch]      main -> main
